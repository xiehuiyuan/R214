# %%
import os
import xmltodict
import Bio.UniProt.GOA as GOA
from ftplib import FTP
import gzip
import numpy as np

# %%
cur_path = os.getcwd()
print(cur_path)
data_folder = '../data'
# Out:
# /Users/xhy/Desktop/CL/ACS/Modules/R214/Practical/Main-Practical/hx255/code

# %%
gaf_uri = '/pub/databases/GO/goa/HUMAN/goa_human.gaf.gz'
gaf_name = gaf_uri.split('/')[-1]

# Check if the file exists already
gaf_path = os.path.join(data_folder, gaf_name)
if(not os.path.isfile(gaf_path)):
    # Login to FTP server
    ebi_ftp = FTP('ftp.ebi.ac.uk')
    ebi_ftp.login() # Logs in anonymously
    
    # Download
    print('Downloading GAF from GOA ftp site...')
    with open(gaf_path,'wb') as f:
        ebi_ftp.retrbinary('RETR {}'.format(gaf_uri), f.write)
        
    # Logout from FTP server
    ebi_ftp.quit()

# %%
# File is a gunzip file, so we need to open it in this way
with gzip.open(gaf_path, 'rt') as f:
    goa = {}  # Initialise the dictionary of functions
    
    # Iterate on each function using Bio.UniProt.GOA library.
    for entry in GOA.gafiterator(f):
        uniprot_id = entry.pop('DB_Object_ID')
        goa[uniprot_id] = entry

# %%
# construct dict mapping from env conditions to GO_ID
cond2go = {
    # ionizing radiation
    'cellular response to gamma radiation': 'GO:0071480',
    'response to x-ray': 'GO:0010165',
    # light stimulus
    'response to UV': 'GO:0009411', # further to UV_A/B/C
    # toxic substance
    'response to nicotine': 'GO:0035094',
    #'cellular response to benomyl': 'GO:0072755',
    #'response to amitrole': 'GO:0072722',
    #'response to paraquat': 'GO:1901562',
    # toxic
    'response to lead ion': 'GO:0010288',
    'response to cadmium ion': 'GO:0046686',
    'response to mercury ion': 'GO:0046689',
    'response to arsenic-containing substance': 'GO:0046685',
}
cond_list = ['cellular response to gamma radiation', 'response to x-ray', 'response to UV',
            'response to nicotine', 'response to lead ion', 'response to cadmium ion', 'response to mercury ion', 'response to arsenic-containing substance']

# %%
def invertdict(d):
    new_d = {v: k for k, v in d.items()}
    return new_d

go2cond = invertdict(cond2go)
print(go2cond)
# Out:
# {'GO:0071480': 'cellular response to gamma radiation', 'GO:0010165': 'response to x-ray', 'GO:0009411': 'response to UV', 'GO:0035094': 'response to nicotine', 'GO:0010288': 'response to lead ion', 'GO:0046686': 'response to cadmium ion', 'GO:0046689': 'response to mercury ion', 'GO:0046685': 'response to arsenic-containing substance'}

# %%
# preprocess cond_amigo_all.txt to cond_amigo_gene.txt
ori_file = os.path.join(data_folder, 'cond_amigo_all.txt')
amigo_file = os.path.join(data_folder, 'cond_amigo_gene.txt')
if (not os.path.isfile(amigo_file)):
    with open(ori_file, 'r') as fi:
        with open(amigo_file, 'w') as fo:
            for line in fi.readlines():
                split = line.strip().split('\t')
                print(split)
                if (split[4] in cond_list) and (split[11]=='gene'):
                    fo.write(line)

# %%
# construct dict recording association between condition GO_IDs and genes
cond_genes = {}
with open(amigo_file, 'r') as f:
    for line in f.readlines():
        split = line.strip().split('\t')
        if split[4] in go2cond.keys():
            if go2cond[split[4]] in cond_genes.keys():
                cond_genes[go2cond[split[4]]].add(split[2].upper())
            else:
                cond_genes[go2cond[split[4]]] = {split[2].upper()} # create a set

# %%
old_dis_list = ['lung neoplasms', 'diabetes mellitus', 'asthma', 'parkinson disease', 'obesity']
dis_list = ['lung neoplasms', 'skin neoplasms', 'diarrhea', 'diabetes mellitus', 'asthma', 'parkinson disease']
# disease appears in 'PheGenI_Association_full.tab'
# ori_phegeni_file = os.path.join(data_folder, 'PheGenI_Association_full.tab')

# disease appears in 'all_gene_disease_associations.tsv' from DisGeNET (more association entries)
ori_disgenet_file = os.path.join(data_folder, 'all_gene_disease_associations.tsv')

# preprocess phegeni file, extract useful lines
# phegeni_file = os.path.join(data_folder, 'PheGenI_Association_extracted.tab')
# with open(ori_phegeni_file, 'r') as fi:
#     with open(phegeni_file, 'w') as fo:
#         for line in fi.readlines():
#             split = line.strip().split('\t')
#             for dis in dis_list:
#                 if dis in split[1].lower(): # split[1] is 'Trait'
#                     split[1] = dis
#                     new_line = '\t'.join(split)
#                     fo.write(new_line)
#                     fo.write('\n')

# preprocess disgenet file, extract useful lines
disgenet_file = os.path.join(data_folder, 'extracted_gene_disease_associations.tsv')
with open(ori_disgenet_file, 'r', errors='replace') as fi:
    with open(disgenet_file, 'w') as fo:
        for line in fi.readlines():
            split = line.strip().split('\t')
            for dis in dis_list:
                if dis in split[3].lower(): # split[3] is 'trait'
                    split[3] = dis
                    new_line = '\t'.join(split)
                    print(new_line)
                    fo.write(new_line)
                    fo.write('\n')
# Out:
# 10	NAT2	C0004096	asthma	0.0275762208930204	12	2	BEFREE;GAD
# 10	NAT2	C0011849	diabetes mellitus	0.00809642307981595	4	0	BEFREE;GAD;LHGDN
# 10	NAT2	C0011854	diabetes mellitus	0.0026817553075011	1	0	BEFREE;GAD
# 10	NAT2	C0011860	diabetes mellitus	0.0026817553075011	2	0	BEFREE;GAD
# 10	NAT2	C0024121	lung neoplasms	0.0178268514875933	7	0	GAD;LHGDN
# 10	NAT2	C0030567	parkinson disease	0.0320086512204254	16	0	BEFREE;GAD;LHGDN
# 10	NAT2	C0155877	asthma	0.0005494535684262	2	0	BEFREE
# 10	NAT2	C0264423	asthma	0.0002747267842131	1	0	BEFREE
# 10	NAT2	C4275179	parkinson disease	0.0005494535684262	2	0	BEFREE
# 100	ADA	C0004096	asthma	0.21105290517153	6	0	BEFREE;GAD;HPO;LHGDN
# 100	ADA	C0011849	diabetes mellitus	0.0016483607052786	6	0	BEFREE
# 100	ADA	C0011854	diabetes mellitus	0.0080452659225033	6	0	BEFREE;GAD
# 100	ADA	C0011860	diabetes mellitus	0.0067371445360677	8	0	BEFREE;GAD
# 100	ADA	C0011991	diarrhea	0.2	0	0	HPO
# 100	ADA	C0024121	lung neoplasms	0.2	1	0	CTD_human
# 100	ADA	C0342276	diabetes mellitus	0.0016483607052786	6	0	BEFREE
# 100	ADA	C0401151	diarrhea	0.2	0	0	HPO
# 10000	AKT3	C0011860	diabetes mellitus	0.0002747267842131	1	1	BEFREE
# 100008588	RNA18S5	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100048912	CDKN2B-AS1	C0011849	diabetes mellitus	0.0002747267842131	1	5	BEFREE
# 100048912	CDKN2B-AS1	C0011860	diabetes mellitus	0.0002747267842131	1	6	BEFREE
# 100049587	SIGLEC14	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10005	ACOT8	C0011991	diarrhea	0.0008241803526393	3	0	BEFREE
# 10005	ACOT8	C0578159	diarrhea	0.0002747267842131	1	0	BEFREE
# 100125288	ZGLP1	C0011849	diabetes mellitus	0.0035714481947703	13	0	BEFREE
# 100125288	ZGLP1	C0011854	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 100125288	ZGLP1	C0011860	diabetes mellitus	0.0046703553316227	17	0	BEFREE
# 100125288	ZGLP1	C0342276	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100126299	VTRNA2-1	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 100126327	MIR938	C0024121	lung neoplasms	0.2	1	0	CTD_human
# 100126340	MIR944	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 100128922	LOC100128922	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 100128998	C20orf181	C0011849	diabetes mellitus	0.0008241803526393	3	0	BEFREE
# 100128998	C20orf181	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100129583	FAM47E	C0030567	parkinson disease	0.0002747267842131	1	1	BEFREE
# 10013	HDAC6	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10013	HDAC6	C0030567	parkinson disease	0.002407028523288	1	0	GAD
# 10013	HDAC6	C0037286	skin neoplasms	0.0002747267842131	1	0	BEFREE
# 100130009	HMGA1P8	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100130097	KIF28P	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100130958	SYCE1L	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 100132074	FOXO6	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100132074	FOXO6	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100132285	KIR2DS2	C0011849	diabetes mellitus	0.00328236603323995	3	0	BEFREE;LHGDN
# 100132285	KIR2DS2	C0011854	diabetes mellitus	0.0050887838307891	3	0	BEFREE;GAD
# 100133790	MUC3	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 100133941	CD24	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 10016	PDCD6	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 10018	BCL2L11	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 100187716	MIR1224	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 100188011	DIP	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100188782	NIDDM4	C0011860	diabetes mellitus	0.2	0	0	CTD_human
# 100188782	NIDDM4	C1842642	diabetes mellitus	0.2	0	0	CTD_human
# 100188784	AFA1	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 100188801	ASRT3	C1864959	asthma	0.2	0	0	CTD_human
# 100188823	ASRT4	C1970474	asthma	0.2	0	0	CTD_human
# 100188840	ASRT6	C1969640	asthma	0.2	0	0	CTD_human
# 100188881	MFT2	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 10019	SH2B3	C0004096	asthma	0.002407028523288	1	0	GAD
# 10019	SH2B3	C0011849	diabetes mellitus	0.0002747267842131	1	1	BEFREE
# 10019	SH2B3	C0011854	diabetes mellitus	0.210727021230004	7	1	BEFREE;CTD_human;GAD
# 100271687	LNCR3	C0024121	lung neoplasms	0.2	0	0	CTD_human
# 100271693	LNCR4	C0024121	lung neoplasms	0.2	0	0	CTD_human
# 100271697	IDDM23	C2675472	diabetes mellitus	0.2	0	0	CTD_human
# 100287171	WASHC1	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 100289462	DEFB4B	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100293534	C4B_2	C0011854	diabetes mellitus	0.0008241803526393	3	0	BEFREE
# 100293534	C4B_2	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100293534	C4B_2	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 100303715	IDDM24	C2751697	diabetes mellitus	0.2	0	0	CTD_human
# 100329167	AAA1	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 100329167	AAA1	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100359403	PARK16	C0030567	parkinson disease	0.208451017775976	22	0	BEFREE;CTD_human;GAD
# 100359403	PARK16	C2751012	parkinson disease	0.2	0	0	CTD_human
# 100415896	ASRT8	C2750782	asthma	0.2	0	0	CTD_human
# 100422880	MIR3162	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 100422880	MIR3162	C0264408	asthma	0.0002747267842131	1	0	BEFREE
# 100422934	MIR3143	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 10044	SH2D3C	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 10049	DNAJB6	C0030567	parkinson disease	0.0008241803526393	3	0	BEFREE
# 100500880	MIR3662	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 100506013	APELA	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 100506248	LOC100506248	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100506736	SLFN12L	C0011854	diabetes mellitus	0.002407028523288	1	0	GAD
# 100506742	CASP12	C0011854	diabetes mellitus	0.200274726784213	2	0	BEFREE;CTD_human
# 100506742	CASP12	C0011860	diabetes mellitus	0.08	1	0	RGD
# 100507056	CCAT1	C0024121	lung neoplasms	0.2	1	0	CTD_human
# 100507436	MICA	C0011849	diabetes mellitus	0.0008241803526393	3	0	BEFREE
# 100507436	MICA	C0011854	diabetes mellitus	0.0191125264713507	21	0	BEFREE;GAD
# 100507436	MICA	C0011860	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 100507436	MICA	C1960272	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 100526664	LY75-CD302	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100528032	KLRC4-KLRK1	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 100532731	COMMD3-BMI1	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 100532731	COMMD3-BMI1	C0037286	skin neoplasms	0.0002747267842131	1	0	BEFREE
# 100532736	MINOS1-NBL1	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 10058	ABCB6	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10059	DNM1L	C0011860	diabetes mellitus	0.08	1	0	RGD
# 10059	DNM1L	C0030567	parkinson disease	0.0024725410579179	9	0	BEFREE
# 10059	DNM1L	C3489791	parkinson disease	0.0002747267842131	1	0	BEFREE
# 100616102	ERVK-9	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
#
diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10555	AGPAT2	C0011849	diabetes mellitus	0.200549453568426	2	2	BEFREE;HPO
# 10555	AGPAT2	C0011859	diabetes mellitus	0.2	0	0	ORPHANET
# 10555	AGPAT2	C1837792	diabetes mellitus	0.2	0	0	HPO
# 1056	CEL	C0004096	asthma	0.0008241803526393	3	0	BEFREE
# 1056	CEL	C0011849	diabetes mellitus	0.0019230874894917	7	0	BEFREE
# 1056	CEL	C0011860	diabetes mellitus	0.200274726784213	1	0	BEFREE;ORPHANET
# 1056	CEL	C0342276	diabetes mellitus	0.201373633921065	5	0	BEFREE;HPO
# 10560	SLC19A2	C0011849	diabetes mellitus	0.201923087489492	7	0	BEFREE;HPO
# 10560	SLC19A2	C0011860	diabetes mellitus	0.0026817553075011	1	0	BEFREE;GAD
# 10560	SLC19A2	C0011991	diarrhea	0.2	0	0	HPO
# 10560	SLC19A2	C0158981	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10563	CXCL13	C0004096	asthma	0.002407028523288	1	0	GAD
# 10565	ARFGEF1	C0004096	asthma	0.002407028523288	1	0	GAD
# 10569	SLU7	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 10569	SLU7	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 10573	MRPL28	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 10577	NPC2	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10577	NPC2	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 10578	GNLY	C0004096	asthma	0.002407028523288	1	0	GAD
# 10580	SORBS1	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10580	SORBS1	C0011849	diabetes mellitus	0.0008241803526393	3	2	BEFREE
# 10580	SORBS1	C0011860	diabetes mellitus	0.0026817553075011	1	1	BEFREE;GAD
# 10587	TXNRD2	C0011860	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 10595	ERN2	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10598	AHSA1	C0004096	asthma	0.0008241803526393	3	0	BEFREE
# 10598	AHSA1	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10598	AHSA1	C0011860	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 10598	AHSA1	C0030567	parkinson disease	0.0008241803526393	3	0	BEFREE
# 10598	AHSA1	C3489791	parkinson disease	0.0002747267842131	1	0	BEFREE
# 10599	SLCO1B1	C0011849	diabetes mellitus	0.002407028523288	1	0	GAD
# 10599	SLCO1B1	C0011860	diabetes mellitus	0.0050887838307891	2	0	BEFREE;GAD
# 10611	PDLIM5	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 10628	TXNIP	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10628	TXNIP	C0011849	diabetes mellitus	0.00712854101222335	17	2	BEFREE;LHGDN
# 10628	TXNIP	C0011854	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 10628	TXNIP	C0011860	diabetes mellitus	0.00575490709115785	11	0	BEFREE;LHGDN
# 10631	POSTN	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 10631	POSTN	C1319853	asthma	0.2	1	0	CTD_human
# 10641	NPRL2	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 10642	IGF2BP1	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 10642	IGF2BP1	C0024121	lung neoplasms	0.00300763924902685	2	0	BEFREE;LHGDN
# 10643	IGF2BP3	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 10644	IGF2BP2	C0011849	diabetes mellitus	0.0112764747984306	10	3	BEFREE;GAD
# 10644	IGF2BP2	C0011854	diabetes mellitus	0.0026817553075011	2	1	BEFREE;GAD
# 10644	IGF2BP2	C0011860	diabetes mellitus	0.292087978505376	89	6	BEFREE;CTD_human;GAD
# 106479034	LARP1BP2	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
#
diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 112464	PRKCDBP	C0024121	lung neoplasms	0.0054658249296275	2	0	LHGDN
# 112476	PRRT2	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 112476	PRRT2	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 11251	PTGDR2	C0004096	asthma	0.21538302118431	13	1	BEFREE;CTD_human;GAD;LHGDN
# 11251	PTGDR2	C0155877	asthma	0.0002747267842131	1	0	BEFREE
# 11251	PTGDR2	C1319853	asthma	0.2	1	0	CTD_human
# 11255	HRH3	C0004096	asthma	0.002407028523288	1	0	GAD
# 11255	HRH3	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 11261	CHP1	C0030567	parkinson disease	0.002407028523288	1	0	GAD
# 11266	DUSP12	C0011860	diabetes mellitus	0.0050887838307891	2	0	BEFREE;GAD
# 11274	USP18	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 112744	IL17F	C0004096	asthma	0.0046048427969928	8	2	BEFREE;GAD
# 112744	IL17F	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 112744	IL17F	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 112755	STX1B	C0030567	parkinson disease	0.0008241803526393	3	0	BEFREE
# 11278	KLF12	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 11279	KLF8	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 1128	CHRM1	C0004096	asthma	0.00809642307981595	2	0	BEFREE;GAD;LHGDN
# 11280	SCN11A	C0011991	diarrhea	0.2	0	0	HPO
# 1129	CHRM2	C0004096	asthma	0.0053635106150022	4	1	BEFREE;GAD
# 1129	CHRM2	C0011853	diabetes mellitus	0.2	1	0	CTD_human
# 1129	CHRM2	C0011854	diabetes mellitus	0.2	1	0	CTD_human
# 112939	NACC1	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 1131	CHRM3	C0004096	asthma	0.0110529051715302	7	0	BEFREE;GAD;LHGDN
# 1131	CHRM3	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 1131	CHRM3	C0011860	diabetes mellitus	0.0002747267842131	1	1	BEFREE
# 113130	CDCA5	C0011854	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 11315	PARK7	C0030567	parkinson disease	0.305236237771581	96	6	BEFREE;CTD_human;GAD;LHGDN
# 11315	PARK7	C1853445	parkinson disease	0.481373633921066	9	5	BEFREE;CTD_human;MGD;UNIPROT
# 11315	PARK7	C3160718	parkinson disease	0.0002747267842131	1	2	BEFREE
# ...
# 9423	NTN1	C0024121	lung neoplasms	0.00300763924902685	1	0	BEFREE;LHGDN
# 9429	ABCG2	C0011849	diabetes mellitus	0.0010989071368524	4	0	BEFREE
# 9429	ABCG2	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9429	ABCG2	C0011860	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 9429	ABCG2	C0011991	diarrhea	0.0064624177518546	7	1	BEFREE;GAD
# 9429	ABCG2	C0024121	lung neoplasms	0.0130127944410173	5	0	GAD;LHGDN
# 9429	ABCG2	C1443924	diarrhea	0.0002747267842131	1	0	BEFREE
# 9429	ABCG2	C1996989	diarrhea	0.0002747267842131	1	0	BEFREE
# 943	TNFRSF8	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 943	TNFRSF8	C0011854	diabetes mellitus	0.002407028523288	1	0	GAD
# 9437	NCR1	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
#
diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9575	CLOCK	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 9575	CLOCK	C0011849	diabetes mellitus	0.0008241803526393	3	0	BEFREE
# 9575	CLOCK	C0011860	diabetes mellitus	0.0010989071368524	4	1	BEFREE
# 9575	CLOCK	C0037286	skin neoplasms	0.0002747267842131	1	0	BEFREE
# 958	CD40	C0004096	asthma	0.091653515897269	7	0	BEFREE;GAD;LHGDN;RGD
# 958	CD40	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 958	CD40	C0011854	diabetes mellitus	0.0059129641834284	6	0	BEFREE;GAD
# 958	CD40	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 958	CD40	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 9580	SOX13	C0011849	diabetes mellitus	0.0010989071368524	4	0	BEFREE
# 9580	SOX13	C0011854	diabetes mellitus	0.0016483607052786	6	0	BEFREE
# 9580	SOX13	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9588	PRDX6	C0024121	lung neoplasms	0.200274726784213	2	0	BEFREE;CTD_human
# 959	CD40LG	C0004096	asthma	0.002407028523288	1	0	GAD
# 959	CD40LG	C0011849	diabetes mellitus	0.0008241803526393	3	0	BEFREE
# 959	CD40LG	C0011853	diabetes mellitus	0.08	1	0	RGD
# 959	CD40LG	C0011854	diabetes mellitus	0.0805494535684262	3	0	BEFREE;RGD
# 959	CD40LG	C0011860	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 959	CD40LG	C0011991	diarrhea	0.2	0	0	HPO
# 959	CD40LG	C0024121	lung neoplasms	0.0054658249296275	2	0	LHGDN
# 960	CD44	C0004096	asthma	0.0008241803526393	3	0	BEFREE
# 960	CD44	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 960	CD44	C0011860	diabetes mellitus	0.0010989071368524	4	0	BEFREE
# 960	CD44	C0024121	lung neoplasms	0.0065647320664799	6	0	BEFREE;LHGDN
# 960	CD44	C0037286	skin neoplasms	0.0002747267842131	1	0	BEFREE
# 9607	CARTPT	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9607	CARTPT	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 9612	NCOR2	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9619	ABCG1	C0011849	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 9619	ABCG1	C0011860	diabetes mellitus	0.00410654638587925	5	0	BEFREE;LHGDN
# 962	CD48	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 9622	KLK4	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 9623	TCL1B	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 9627	SNCAIP	C0030567	parkinson disease	0.031362067474026	32	4	BEFREE;GAD;LHGDN
# 9627	SNCAIP	C3160718	parkinson disease	0.2	0	0	CTD_human
# 963	CD53	C0004096	asthma	0.0002747267842131	1	0	BEFREE
# 963	CD53	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 9636	ISG15	C0011853	diabetes mellitus	0.08	1	0	RGD
# 9636	ISG15	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 965	CD58	C0011854	diabetes mellitus	0.002407028523288	1	0	GAD
# 9652	TTC37	C0011991	diarrhea	0.2	0	0	HPO
# 9652	TTC37	C0743178	diarrhea	0.200549453568426	2	0	BEFREE;HPO
# 9655	SOCS5	C0011854	diabetes mellitus	0.002407028523288	1	0	GAD
# 966	CD59	C0011849	diabetes mellitus	0.0016483607052786	6	0	BEFREE
# 966	CD59	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
#
diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9940	DLEC1	C0024121	lung neoplasms	0.2	0	0	CTD_human
# 9941	EXOG	C0011860	diabetes mellitus	0.0026817553075011	1	0	BEFREE;GAD
# 9945	GFPT2	C0011860	diabetes mellitus	0.0050887838307891	2	1	BEFREE;GAD
# 995	CDC25C	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9958	USP15	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 9961	MVP	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9961	MVP	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9961	MVP	C0030567	parkinson disease	0.0002747267842131	1	0	BEFREE
# 9965	FGF19	C0011849	diabetes mellitus	0.0010989071368524	4	0	BEFREE
# 9965	FGF19	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9965	FGF19	C0011991	diarrhea	0.0005494535684262	2	0	BEFREE
# 9966	TNFSF15	C0011849	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9966	TNFSF15	C0011854	diabetes mellitus	0.002407028523288	1	1	GAD
# 9967	THRAP3	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9970	NR1I3	C0011849	diabetes mellitus	0.2	1	0	CTD_human
# 9970	NR1I3	C0011853	diabetes mellitus	0.08	1	0	RGD
# 9970	NR1I3	C0011860	diabetes mellitus	0.0002747267842131	1	0	BEFREE
# 9971	NR1H4	C0011849	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 9971	NR1H4	C0011860	diabetes mellitus	0.0010989071368524	4	0	BEFREE
# 998	CDC42	C0011991	diarrhea	0.0002747267842131	1	0	BEFREE
# 998	CDC42	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 998	CDC42	C0030567	parkinson disease	0.0026817553075011	2	0	BEFREE;GAD
# 9984	THOC1	C0024121	lung neoplasms	0.0002747267842131	1	0	BEFREE
# 9988	DMTF1	C0024121	lung neoplasms	0.00273291246481375	1	0	LHGDN
# 999	CDH1	C0004096	asthma	0.00568939455652795	4	0	BEFREE;GAD;LHGDN
# 999	CDH1	C0024121	lung neoplasms	0.014214015892495	7	0	BEFREE;LHGDN
# 999	CDH1	C0264408	asthma	0.0002747267842131	1	0	BEFREE
# 9992	KCNE2	C0011853	diabetes mellitus	0.08	1	0	RGD
# 9992	KCNE2	C0011860	diabetes mellitus	0.002407028523288	1	0	GAD
# 9993	DGCR2	C0011849	diabetes mellitus	0.0005494535684262	2	0	BEFREE
# 9993	DGCR2	C0011854	diabetes mellitus	0.0002747267842131	1	0	BEFREE

# %%
# construct dict recording associations between diseases and genes
dis_genes = {}

with open(disgenet_file, 'r', errors='replace') as f:
    for line in f.readlines():
        split = line.strip().split('\t')
        if split[3] in dis_genes.keys():
            dis_genes[split[3]].add(split[1].upper())
            # dis_genes[split[1]].add(split[6].upper())
        else:
            dis_genes[split[3]] = {split[1].upper()}
            # dis_genes[split[1]].add(split[6].upper())
print(dis_genes)
# Out:
# {'asthma': {'MYOM2', 'HLA-DPA1', 'OPN3', 'IFNA8', 'CAV1', 'IL17F', 'PPP2CA', 'PNOC', 'SYT1', 'CXCL16', 'PTGER1', 'TP63', 'PDE4D', 'TAC4', 'PRH2', 'FTO', 'RRBP1', 'RBP7', 'SLC22A5', 'CKLF', 'MYH11', 'SLC22A2', 'CYP1A1', 'EPHB2', 'PC', 'CSMD1', 'CSE', 'LAT', 'ZFP36', 'CCL23', 'RUNX3', 'CCL18', 'ABCA1', 'RELA', 'CHIA', 'CFL1', 'CXCL10', 'HLA-C', 'FBRS', 'GIMAP4', 'SH2B1', 'IL4', 'TRAF6', 'IL15', 'HSPA1A', 'STAT5B', 'CDSN', 'ADORA1', 'SGCG', 'CTNNA3', 'RPLP0', 'HLA-DQB1', 'SLC52A2', 'HIST1H4C', 'CTNNBL1', 'EPHX2', 'FHL2', 'MIR19A', 'SLC22A1', 'CYP1A2', 'COX1', 'MAPK9', 'GSTK1', 'CDIP1', 'CMA1', 'CTLA4', 'SERPINB3', 'CHRM1', 'NTF4', 'TRAC', 'DCLK3', 'SERPINE2', 'UCN', 'KAT2B', 'PAX5', 'HIST1H4H', 'VCAN', 'S1PR1', 'MUSK', 'HLA-DQA2', 'IL13RA2', 'SLC52A1', 'CD28', 'GGTLC5P', 'KITLG', 'MAS1', 'ORMDL3', 'NM', 'CXCL12', 'NTF3', 'KIF3A', 'HIST1H4J', 'HIST1H4B', 'SULT1A1', 'ARSA', 'ABCD1', 'PRG2', 'LIPG', 'CCR6', 'RGS7BP', 'ACVR1', 'NOS1', 'IFNL2', 'SDF4', 'CCL24', 'PLB1', 'LINC01193', 'HIST1H4E', 'PTAFR', 'GSTM2', 'PSORS1C1', 'AGTR1', 'HLA-DOA', 'PMCH', 'BCDIN3D', 'FSTL1', 'ITGA4', 'ARG2', 'RAF1', 'F10', 'CNGB1', 'TNFAIP1', 'CCL28', 'FCER1A', 'PTGIR', 'AGA', 'FCGR1A', 'GGTLC4P', 'LPAR2', 'MICE', 'SPATS2L', 'CD44', 'APRT', 'AICDA', 'TAPBP', 'TET1', 'ALOX5', 'CD200', 'PRRC2A', 'IL17A', 'CASP1', 'GATA3', 'PDE11A', 'ROM1', 'CAT', 'SELENBP1', 'CRTAM', 'HAVCR2', 'PRMT1', 'CRHR2', 'PIK3CD', 'PRH1', 'COPD', 'MIR223', 'AHR', 'GRIK2', 'C3AR1', 'SOD1', 'HDAC6', 'CCHCR1', 'CHML', 'CYP4F3', 'MAPK8', 'LTB4R', 'CXCL6', 'CEBPA', 'TMED1', 'NOX3', 'CTNND1', 'TRPV4', 'CCL1', 'TNFRSF14', 'MIR140', 'CDHR3', 'CDKN1C', 'COL4A5', 'ANXA2', 'HDAC1', 'TMEM219', 'ADM', 'PTPN22', 'LNPEP', 'CRIP1', 'COL26A1', 'AURKB', 'SELENOS', 'CYP11A1', 'CYP2E1', 'BMPR2', 'GYPA', 'GNLY', 'B3GAT1', 'CYBA', 'MFGE8', 'ENPP1', 'AGER', 'STIP1', 'IL24', 'SIGLEC8', 'DUSP1', 'CX3CL1', 'ADORA2A', 'RTEL1', 'EFNA1', 'RNASE2', 'CHRM3', 'IL2RA', 'HAVCR1', 'PSMB6', 'CRIM1', 'LIG4', 'MIP', 'MTCH2', 'CXCL14', 'GRK2', 'CTSS', 'PDIA3', 'GGT1', 'ASRT4', 'VIP', 'FLT3LG', 'CXCR1', 'RAB27A', 'ACTA1', 'MAPK1', 'CKAP4', 'RIOX2', 'LRRN2', 'HDAC2', 'FOSL1', 'ATPAF1', 'ACAA1', 'TSLP', 'MARCKS', 'SFTPD', 'TMEM18', 'EPX', 'GSTM1', 'SERPINB2', 'CDH17', 'HRH1', 'PLF', 'MMRN1', 'CETP', 'FUT2', 'IL12RB2', 'RIPK2', 'YWHAZ', 'MUC19', 'ADAMTS12', 'ADAMTSL1', 'FOXP3', 'PARP1', 'ADRA2B', 'XDH', 'TLR1', 'TGFB2', 'NR1I2', 'ZBTB10', 'TLR9', 'ISYNA1', 'SNW1', 'GBE1', 'SELL', 'IL18RAP', 'RBMS3', 'GSN', 'SIGIRR', 'CTGF', 'SP1', 'EEF1A2', 'CDH1', 'LTA', 'TIMP3', 'TLR6', 'MUC5AC', 'CYP2R1', 'CLCA1', 'EHF', 'HEXB', 'FGF2', 'DCTN4', 'CACNG6', 'IGHG1', 'IL23A', 'IL12RB1', 'PTGS2', 'PRRT2', 'MIR146B', 'LTC4S', 'CPA4', 'INSIG2', 'CD53', 'VEGFA', 'ATM', 'HSPA4', 'IL17D', 'AKR1B1', 'RAPSN', 'RABEPK', 'LTB4R2', 'IL33', 'TUSC3', 'FRMD6', 'FCRL3', 'CALM1', 'JUND', 'PEBP1', 'KCNS3', 'HIST1H4L', 'TPT1', 'MIR146A', 'HIST1H4F', 'SIGLEC14', 'CD177', 'CTNNAL1', 'NBR1', 'MYLK', 'CD80', 'BRS3', 'SLC45A2', 'CXCL1', 'C5', 'UGT1A6', 'GRP', 'F2RL1', 'FCGR3B', 'TIPARP', 'TRA', 'RPSA', 'CDR3', 'PCDH1', 'ABCC1', 'CYP3A4', 'TBXA2R', 'FCAR', 'NOX4', 'S100A8', 'LOC102723996', 'IL17RA', 'FCGR2B', 'IFNG', 'PCNA', 'AGTR2', 'PON1', 'PRNP', 'IGES', 'TIMD4', 'EDNRA', 'FSIP1', 'SLPI', 'TMPRSS11D', 'IL1B', 'FADS1', 'CXCR2', 'SNORA73B', 'IL5', 'PHC1', 'KLK1', 'DENND1B', 'ACKR1', 'TRG', 'RASGRP4', 'MRC1', 'TNC', 'WIF1', 'COL3A1', 'BACH2', 'TRAF2', 'TBPL1', 'NEUROD1', 'ACSL3', 'FUT3', 'LPA', 'ST13', 'ERO1B', 'MZF1', 'IL19', 'ATF6', 'CTNNA1', 'KLRB1', 'GSDMB', 'CCL3L1', 'IL10RA', 'TLR3', 'WG', 'NQO1', 'TGFBI', 'GRM1', 'SOAT1', 'LIFR', 'CTTN', 'NPS', 'AXL', 'FGA', 'LDLR', 'TACR1', 'CLDN7', 'ODC1', 'SERPINE1', 'ORM1', 'TNFRSF10B', 'TGFB3', 'IRF3', 'DNASE1L3', 'INHA', 'SERPING1', 'JUNB', 'FCGRT', 'PPARA', 'NGF', 'COMMD10', 'RBM45', 'TSC22D3', 'CASP9', 'ANK1', 'WDHD1', 'C4A', 'HLA-DRA', 'IL4R', 'RNU1-1', 'GIMAP5', 'BRD4', 'TUBB4B', 'NAA25', 'APC', 'FYN', 'FCER1G', 'CCL26', 'LRBA', 'RACK1', 'ANGPT1', 'ARG1', 'TLN1', 'CCL22', 'EGFR', 'MUC7', 'RHD', 'PRMT3', 'TENM3', 'IGS ...

# %%
# Jaccard index
def jaccard_index(set1, set2):
    n = len(set1.intersection(set2))
    return n / (len(set1) + len(set2) - n)

# %%
# direct (unenriched) Jaccard index between conditions and diseases
direct_jac = np.zeros((len(cond_list), len(dis_list)))
for cond_idx, cond in enumerate(cond_list):
    for dis_idx, dis in enumerate(dis_list):
        direct_jac[cond_idx][dis_idx] = jaccard_index(cond_genes[cond], dis_genes[dis])

for i in range(len(direct_jac)):
    print(direct_jac[i])
print()
#print(cond_genes['response to nicotine'])
#print(dis_genes['lung neoplasms'])
print(cond_list)
print(dis_list)
for i in range(len(direct_jac)):
    for j in range(len(direct_jac[i])):
        direct_jac[i][j] = direct_jac[i][j] * 50
for i in range(len(direct_jac)):
    print(direct_jac[i])
# Out:
# [ 0.00999167  0.0128866   0.00222717  0.00487465  0.00487126  0.00618375]
# [ 0.01495017  0.01772152  0.01101322  0.00590688  0.00693001  0.00790167]
# [ 0.01456311  0.03333333  0.00614754  0.00446122  0.00677966  0.00768574]
# [ 0.02052545  0.02919708  0.00840336  0.01214856  0.01305842  0.0254386 ]
# [ 0.01244813  0.01010101  0.01555556  0.00801394  0.00833912  0.01415929]
# [ 0.01139138  0.01438849  0.01265823  0.00690608  0.00889802  0.00862813]
# [ 0.00405515  0.00239808  0.0021097   0.00310131  0.00273038  0.00344828]
# [ 0.00748752  0.00773196  0.01128668  0.00347947  0.00487805  0.00441696]
#
# ['cellular response to gamma radiation', 'response to x-ray', 'response to UV', 'response to nicotine', 'response to lead ion', 'response to cadmium ion', 'response to mercury ion', 'response to arsenic-containing substance']
# ['lung neoplasms', 'skin neoplasms', 'diarrhea', 'diabetes mellitus', 'asthma', 'parkinson disease']
# [ 0.49958368  0.6443299   0.11135857  0.24373259  0.24356298  0.30918728]
# [ 0.74750831  0.88607595  0.55066079  0.29534399  0.34650035  0.39508341]
# [ 0.72815534  1.66666667  0.30737705  0.22306108  0.33898305  0.38428693]
# [ 1.02627258  1.45985401  0.42016807  0.60742798  0.65292096  1.27192982]
# [ 0.62240664  0.50505051  0.77777778  0.40069686  0.41695622  0.7079646 ]
# [ 0.56956876  0.71942446  0.63291139  0.34530387  0.44490075  0.43140638]
# [ 0.2027575   0.11990408  0.10548523  0.15506547  0.13651877  0.17241379]
# [ 0.37437604  0.38659794  0.56433409  0.17397356  0.24390244  0.22084806]

# %%
# download 'go-basic.obo'
from goatools import obo_parser
import wget
go_obo_url = 'http://purl.obolibrary.org/obo/go/go-basic.obo'
if(not os.path.isfile(data_folder+'/go-basic.obo')):
    go_obo = wget.download(go_obo_url, data_folder+'/go-basic.obo')
else:
    go_obo = data_folder+'/go-basic.obo'
go = obo_parser.GODag(go_obo)
# Out:
# load obo file ../data/go-basic.obo
# ../data/go-basic.obo: fmt(1.2) rel(2018-04-14) 47,199 GO Terms

# %%
def common_parent_go_ids(terms, go):
    '''
        This function finds the common ancestors in the GO 
        tree of the list of terms in the input.
    '''
    # Find candidates from first
    rec = go[terms[0]]
    candidates = rec.get_all_parents()
    candidates.update({terms[0]})
    
    # Find intersection with second to nth term
    for term in terms[1:]:
        rec = go[term]
        parents = rec.get_all_parents()
        parents.update({term})
        
        # Find the intersection with the candidates, and update.
        candidates.intersection_update(parents)
        
    return candidates

def deepest_common_ancestor(terms, go):
    return max(common_parent_go_ids(terms, go), key=lambda t: go[t].depth)

# finds the minimum branch length between two terms in the GO DAG
def min_branch_length(go_id1, go_id2, go):
    '''
        Finds the minimum branch length between two terms in the GO DAG.
    '''
    # First get the deepest common ancestor
    dca = deepest_common_ancestor([go_id1, go_id2], go)
    
    # Then get the distance from the DCA to each term
    dca_depth = go[dca].depth
    d1 = go[go_id1].depth - dca_depth
    d2 = go[go_id2].depth - dca_depth
    
    # Return the total distance - i.e., to the deepest common ancestor and back.
    return d1 + d2

# %%
# semantic similarity (1st option) between conditions
def semantic_similarity(go_id1, go_id2, go):
    dist = min_branch_length(go_id1, go_id2, go)
    if dist == 0:
        return -1.0
    return 1.0 / dist

# %%
# calculate semantic similarity
n = len(cond_list)
cond_res_sim = np.zeros((n, n))
for i in range(n):
    go_id1 = cond2go[cond_list[i]]
    for j in range(n):        
        go_id2 = cond2go[cond_list[j]]
        cond_res_sim[i][j] = semantic_similarity(go_id1, go_id2, go)
        print(cond_list[i], cond_list[j])
        print(cond_res_sim[i][j])
print(cond_res_sim)
# Out:
# cellular response to gamma radiation cellular response to gamma radiation
# -1.0
# cellular response to gamma radiation response to x-ray
# 0.25
# cellular response to gamma radiation response to UV
# 0.166666666667
# cellular response to gamma radiation response to nicotine
# 0.111111111111
# cellular response to gamma radiation response to lead ion
# 0.1
# cellular response to gamma radiation response to cadmium ion
# 0.1
# cellular response to gamma radiation response to mercury ion
# 0.1
# cellular response to gamma radiation response to arsenic-containing substance
# 0.125
# response to x-ray cellular response to gamma radiation
# 0.25
# response to x-ray response to x-ray
# -1.0
# response to x-ray response to UV
# 0.25
# response to x-ray response to nicotine
# 0.142857142857
# response to x-ray response to lead ion
# 0.125
# response to x-ray response to cadmium ion
# 0.125
# response to x-ray response to mercury ion
# 0.125
# response to x-ray response to arsenic-containing substance
# 0.166666666667
# response to UV cellular response to gamma radiation
# 0.166666666667
# response to UV response to x-ray
# 0.25
# response to UV response to UV
# -1.0
# response to UV response to nicotine
# 0.142857142857
# response to UV response to lead ion
# 0.125
# response to UV response to cadmium ion
# 0.125
# response to UV response to mercury ion
# 0.125
# response to UV response to arsenic-containing substance
# 0.166666666667
# response to nicotine cellular response to gamma radiation
# 0.111111111111
# response to nicotine response to x-ray
# 0.142857142857
# response to nicotine response to UV
# 0.142857142857
# response to nicotine response to nicotine
# -1.0
# response to nicotine response to lead ion
# 0.2
# response to nicotine response to cadmium ion
# 0.2
# response to nicotine response to mercury ion
# 0.2
# response to nicotine response to arsenic-containing substance
# 0.333333333333
# response to lead ion cellular response to gamma radiation
# 0.1
# response to lead ion response to x-ray
# 0.125
# response to lead ion response to UV
# 0.125
# response to lead ion response to nicotine
# 0.2
# response to lead ion response to lead ion
# -1.0
# response to lead ion response to cadmium ion
# 0.5
# response to lead ion response to mercury ion
# 0.5
# response to lead ion response to arsenic-containing substance
# 0.25
# response to cadmium ion cellular response to gamma radiation
# 0.1
# response to cadmium ion response to x-ray
# 0.125
# response to cadmium ion response to UV
# 0.125
# response to cadmium ion response to nicotine
# 0.2
# response to cadmium ion response to lead ion
# 0.5
# response to cadmium ion response to cadmium ion
# -1.0
# response to cadmium ion response to mercury ion
# 0.5
# response to cadmium ion response to arsenic-containing substance
# 0.25
# response to mercury ion cellular response to gamma radiation
# 0.1
# response to mercury ion response to x-ray
# 0.125
# response to mercury ion response to UV
# 0.125
# response to mercury ion response to nicotine
# 0.2
# response to mercury ion response to lead ion
# 0.5
# response to mercury ion response to cadmium ion
# 0.5
# response to mercury ion response to mercury ion
# -1.0
# response to mercury ion response to arsenic-containing substance
# 0.25
# response to arsenic-containing substance cellular response to gamma radiation
# 0.125
# response to arsenic-containing substance response to x-ray
# 0.166666666667
# response to arsenic-containing substance response to UV
# 0.166666666667
# response to arsenic-containing substance response to nicotine
# 0.333333333333
# response to arsenic-containing substance response to lead ion
# 0.25
# response to arsenic-containing substance response to cadmium ion
# 0.25
# response to arsenic-containing substance response to mercury ion
# 0.25
# response to arsenic-containing substance response to arsenic-containing substance
# -1.0
# [[-1.          0.25        0.16666667  0.11111111  0.1         0.1         0.1
#    0.125     ]
#  [ 0.25       -1.          0.25        0.14285714  0.125       0.125       0.125
#    0.16666667]
#  [ 0.16666667  0.25       -1.          0.14285714  0.125       0.125       0.125
#    0.16666667]
#  [ 0.11111111  0.14285714  0.14285714 -1.          0.2         0.2         0.2
#    0.33333333]
#  [ 0.1         0.125       0.125       0.2        -1.          0.5         0.5
#    0.25      ]
#  [ 0.1         0.125       0.125       0.2         0.5        -1.          0.5
#    0.25      ]
#  [ 0.1         0.125       0.125       0.2         0.5         0.5        -1.
#    0.25      ]
#  [ 0.125       0.16666667  0.16666667  0.33333333  0.25        0.25        0.25
#   -1.        ]]

# %%
import math
from collections import Counter

class TermCounts():
    '''
        TermCounts counts the term counts for each 
    '''
    def __init__(self, go, annots):
        '''
            Initialise the counts and  
        '''
        # Backup
        self._go = go
        
        # Initialise the counters
        self._counts = Counter()
        self._aspect_counts = Counter()
        
        # Fill the counters...
        self._count_terms(go, annots)
        
    def _count_terms(self, go, annots):
        '''
            Fills in the counts and overall aspect counts.
        '''
        for x in annots:
            # Extract term information
            go_id = annots[x]['GO_ID']
            namespace = go[go_id].namespace

            self._counts[go_id] += 1
            rec = go[go_id]
            parents = rec.get_all_parents()
            for p in parents:
                self._counts[p] += 1
            
            self._aspect_counts[namespace] += 1
            
    def get_count(self, go_id):
        '''
            Returns the count of that GO term observed in the annotations.
        '''
        return self._counts[go_id]
        
    def get_total_count(self, aspect):
        '''
            Gets the total count that's been precomputed.
        '''
        return self._aspect_counts[aspect]
    
    def get_term_freq(self, go_id):
        '''
            Returns the frequency at which a particular GO term has 
            been observed in the annotations.
        '''
        try:
            namespace = self._go[go_id].namespace
            freq = float(self.get_count(go_id)) / float(self.get_total_count(namespace))
        except ZeroDivisionError:
            freq = 0
        
        return freq

termcounts = TermCounts(go, goa)

# %%
# information content (IC)
def ic(go_id, termcounts):
    # Get the observed frequency of the GO term
    freq = termcounts.get_term_freq(go_id)
    if freq == 0:
        return -1.0 # not appear
    # Calculate the information content (i.e., -log("freq of GO term")
    return -1.0 * math.log(freq)

# %%
# Resnik's similarity measure: the information content of the most informative common ancestor, i.e. the most specific common parent-term in the GO 
def resnik_sim(go_id1, go_id2, go, termcounts):
    msca = deepest_common_ancestor([go_id1, go_id2], go)
    return ic(msca, termcounts)

# %%
# test
go_id3 = 'GO:0071480'
go_id4 = 'GO:0009411'
go_id5 = 'GO:0010288'
sim_r = resnik_sim(go_id3, go_id4, go, termcounts)
print('Resnik similarity score 1: {}'.format(sim_r))
sim_r = resnik_sim(go_id3, go_id5, go, termcounts)
print('Resnik similarity score 1: {}'.format(sim_r))
# Out:
# Resnik similarity score 1: 6.020052003959894
# Resnik similarity score 1: 2.1249717192620605

# %%
n = len(cond_list)
cond_res_sim = np.zeros((n, n))
for i in range(n):
    go_id1 = cond2go[cond_list[i]]
    for j in range(n):        
        go_id2 = cond2go[cond_list[j]]
        cond_res_sim[i][j] = resnik_sim(go_id1, go_id2, go, termcounts)
        print(cond_list[i], cond_list[j])
        print(cond_res_sim[i][j])
print(cond_res_sim)
# Out:
# cellular response to gamma radiation cellular response to gamma radiation
# 7.62948991639
# cellular response to gamma radiation response to x-ray
# 6.84103255603
# cellular response to gamma radiation response to UV
# 6.02005200396
# cellular response to gamma radiation response to nicotine
# 2.12497171926
# cellular response to gamma radiation response to lead ion
# 2.12497171926
# cellular response to gamma radiation response to cadmium ion
# 2.12497171926
# cellular response to gamma radiation response to mercury ion
# 2.12497171926
# cellular response to gamma radiation response to arsenic-containing substance
# 2.12497171926
# response to x-ray cellular response to gamma radiation
# 6.84103255603
# response to x-ray response to x-ray
# -1.0
# response to x-ray response to UV
# 6.02005200396
# response to x-ray response to nicotine
# 2.12497171926
# response to x-ray response to lead ion
# 2.12497171926
# response to x-ray response to cadmium ion
# 2.12497171926
# response to x-ray response to mercury ion
# 2.12497171926
# response to x-ray response to arsenic-containing substance
# 2.12497171926
# response to UV cellular response to gamma radiation
# 6.02005200396
# response to UV response to x-ray
# 6.02005200396
# response to UV response to UV
# 7.29301767977
# response to UV response to nicotine
# 2.12497171926
# response to UV response to lead ion
# 2.12497171926
# response to UV response to cadmium ion
# 2.12497171926
# response to UV response to mercury ion
# 2.12497171926
# response to UV response to arsenic-containing substance
# 2.12497171926
# response to nicotine cellular response to gamma radiation
# 2.12497171926
# response to nicotine response to x-ray
# 2.12497171926
# response to nicotine response to UV
# 2.12497171926
# response to nicotine response to nicotine
# -1.0
# response to nicotine response to lead ion
# 3.07561302479
# response to nicotine response to cadmium ion
# 3.07561302479
# response to nicotine response to mercury ion
# 3.07561302479
# response to nicotine response to arsenic-containing substance
# 3.07561302479
# response to lead ion cellular response to gamma radiation
# 2.12497171926
# response to lead ion response to x-ray
# 2.12497171926
# response to lead ion response to UV
# 2.12497171926
# response to lead ion response to nicotine
# 3.07561302479
# response to lead ion response to lead ion
# -1.0
# response to lead ion response to cadmium ion
# 5.77319192603
# response to lead ion response to mercury ion
# 5.77319192603
# response to lead ion response to arsenic-containing substance
# 3.07561302479
# response to cadmium ion cellular response to gamma radiation
# 2.12497171926
# response to cadmium ion response to x-ray
# 2.12497171926
# response to cadmium ion response to UV
# 2.12497171926
# response to cadmium ion response to nicotine
# 3.07561302479
# response to cadmium ion response to lead ion
# 5.77319192603
# response to cadmium ion response to cadmium ion
# -1.0
# response to cadmium ion response to mercury ion
# 5.77319192603
# response to cadmium ion response to arsenic-containing substance
# 3.07561302479
# response to mercury ion cellular response to gamma radiation
# 2.12497171926
# response to mercury ion response to x-ray
# 2.12497171926
# response to mercury ion response to UV
# 2.12497171926
# response to mercury ion response to nicotine
# 3.07561302479
# response to mercury ion response to lead ion
# 5.77319192603
# response to mercury ion response to cadmium ion
# 5.77319192603
# response to mercury ion response to mercury ion
# -1.0
# response to mercury ion response to arsenic-containing substance
# 3.07561302479
# response to arsenic-containing substance cellular response to gamma radiation
# 2.12497171926
# response to arsenic-containing substance response to x-ray
# 2.12497171926
# response to arsenic-containing substance response to UV
# 2.12497171926
# response to arsenic-containing substance response to nicotine
# 3.07561302479
# response to arsenic-containing substance response to lead ion
# 3.07561302479
# response to arsenic-containing substance response to cadmium ion
# 3.07561302479
# response to arsenic-containing substance response to mercury ion
# 3.07561302479
# response to arsenic-containing substance response to arsenic-containing substance
# 8.14031554016
# [[ 7.62948992  6.84103256  6.020052    2.12497172  2.12497172  2.12497172
#    2.12497172  2.12497172]
#  [ 6.84103256 -1.          6.020052    2.12497172  2.12497172  2.12497172
#    2.12497172  2.12497172]
#  [ 6.020052    6.020052    7.29301768  2.12497172  2.12497172  2.12497172
#    2.12497172  2.12497172]
#  [ 2.12497172  2.12497172  2.12497172 -1.          3.07561302  3.07561302
#    3.07561302  3.07561302]
#  [ 2.12497172  2.12497172  2.12497172  3.07561302 -1.          5.77319193
#    5.77319193  3.07561302]
#  [ 2.12497172  2.12497172  2.12497172  3.07561302  5.77319193 -1.
#    5.77319193  3.07561302]
#  [ 2.12497172  2.12497172  2.12497172  3.07561302  5.77319193  5.77319193
#   -1.          3.07561302]
#  [ 2.12497172  2.12497172  2.12497172  3.07561302  3.07561302  3.07561302
#    3.07561302  8.14031554]]

# %%
# compartment
cond_comps = {}
for cond in cond_list:
    cond_comps[cond] = list()

comppi_file = os.path.join(data_folder, 'comppi_proteins_locs.txt')
with open(comppi_file, 'r') as f:
    for line in f.readlines():
        split = line.strip().split('\t')
        for cond, genes in cond_genes.items():
            for gene in genes:
                if gene in split[2]:
                    loc = split[3].split(':')[0]
                    cond_comps[cond].append(loc)
                    break
print(cond_comps)
# Out:
# {'cellular response to gamma radiation': ['cytosol', 'cytosol', 'cytosol', 'cytosol', 'membrane', 'mitochondrion', 'cytosol', 'nucleus', 'nucleus', 'cytosol', 'cytosol', 'cytosol', 'nucleus', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 'cytosol', 
        count = comps.count(comp)
        counts.append(count)
    cond_comp_counts[cond] = counts
print(cond_comp_counts)
# Out:
# {'cellular response to gamma radiation': [67, 31, 201, 16, 2, 1], 'response to x-ray': [131, 99, 376, 31, 10, 13], 'response to UV': [109, 117, 326, 19, 20, 4], 'response to nicotine': [173, 364, 585, 73, 29, 29], 'response to lead ion': [374, 218, 759, 79, 17, 20], 'response to cadmium ion': [54, 450, 407, 59, 6, 13], 'response to mercury ion': [476, 563, 1216, 111, 22, 58], 'response to arsenic-containing substance': [10, 19, 70, 7, 0, 1]}

# %%
cond_comp_ratios = {}
new_comp_list = ['nucleus', 'membrane', 'cytosol', 'mitochondrion', 'extracellular']

for cond in cond_comps:
    ratios = []
    counts = cond_comp_counts[cond]
    total_count = 0
    for i in range(len(counts)-1):
        total_count += counts[i]
    for i in range(len(counts)-1):
        ratios.append(counts[i]/total_count)
    cond_comp_ratios[cond] = ratios
for cond, ratios in cond_comp_ratios.items():
    print(cond)
    i = 0
    for ratio in ratios:
        print(new_comp_list[i], '{0:.3f}'.format(ratio))
        i += 1
    print()
print(cond_comp_ratios)
# Out:
# cellular response to gamma radiation
# nucleus 0.211
# membrane 0.098
# cytosol 0.634
# mitochondrion 0.050
# extracellular 0.006
#
# response to x-ray
# nucleus 0.202
# membrane 0.153
# cytosol 0.581
# mitochondrion 0.048
# extracellular 0.015
#
# response to UV
# nucleus 0.184
# membrane 0.198
# cytosol 0.552
# mitochondrion 0.032
# extracellular 0.034
#
# response to nicotine
# nucleus 0.141
# membrane 0.297
# cytosol 0.478
# mitochondrion 0.060
# extracellular 0.024
#
# response to lead ion
# nucleus 0.258
# membrane 0.151
# cytosol 0.525
# mitochondrion 0.055
# extracellular 0.012
#
# response to cadmium ion
# nucleus 0.055
# membrane 0.461
# cytosol 0.417
# mitochondrion 0.060
# extracellular 0.006
#
# response to mercury ion
# nucleus 0.199
# membrane 0.236
# cytosol 0.509
# mitochondrion 0.046
# extracellular 0.009
#
# response to arsenic-containing substance
# nucleus 0.094
# membrane 0.179
# cytosol 0.660
# mitochondrion 0.066
# extracellular 0.000
#
# {'cellular response to gamma radiation': [0.2113564668769716, 0.09779179810725552, 0.6340694006309149, 0.050473186119873815, 0.006309148264984227], 'response to x-ray': [0.20247295208655333, 0.15301391035548687, 0.5811437403400309, 0.04791344667697063, 0.015455950540958269], 'response to UV': [0.1844331641285956, 0.19796954314720813, 0.5516074450084603, 0.032148900169204735, 0.0338409475465313], 'response to nicotine': [0.14133986928104575, 0.2973856209150327, 0.47794117647058826, 0.059640522875817, 0.02369281045751634], 'response to lead ion': [0.25846579129232894, 0.15065653075328264, 0.5245335176226675, 0.05459571527297857, 0.011748445058742226], 'response to cadmium ion': [0.055327868852459015, 0.4610655737704918, 0.41700819672131145, 0.060450819672131145, 0.006147540983606557], 'response to mercury ion': [0.19932998324958123, 0.23576214405360135, 0.509212730318258, 0.04648241206030151, 0.009212730318257957], 'response to arsenic-containing substance': [0.09433962264150944, 0.1792452830188679, 0.660377358490566, 0.0660377358490566, 0.0]}
